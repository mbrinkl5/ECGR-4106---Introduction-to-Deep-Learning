# %% [markdown]
# # ECGR 4106/5106 — Homework 1
#
# CNN Architecture Comparison on CIFAR-10 Using PyTorch
#
# ## Contents
#
# * `ECGR4106_HW_1.ipynb` — Complete notebook (all training runs and plots)
#
# * Homework report (PDF) — Analysis and discussion of all results.
#
# ## Overview
#
#
# - **Problem 1:** Modified AlexNet adapted for 32x32 inputs, plus dropout experiments (p = 0.3, 0.5)
# - **Problem 2:** Adapted VGG-11 (closest parameter count to the AlexNet), same dropout comparison
# - **Problem 3:** ResNet-18 from scratch vs. ResNet-11 baseline, dropout after global average pooling, and a final comparison across all four architectures
#
# ## Training Setup
#
# * Platform: Google Colab
# * Hardware: NVIDIA T4 GPU
# * Optimizer: SGD
# * Learning Rate: 0.001
# * Momentum: 0.9
# * Batch Size: 64
# * Loss Function: CrossEntropyLoss
#
# ### Data Preprocessing
#
# Training images:
#
# * Padding (4 pixels)
# * Random Crop (32×32)
# * Random Horizontal Flip
# * Normalization to mean = (0.5, 0.5, 0.5) and std = (0.5, 0.5, 0.5)
#
# Test images:
#
# * Normalization only
#
# ### Training Schedule
#
# * Problems 1–2: 30 epochs
# * Problem 3: 50 epochs
# * ResNet models used a StepLR scheduler (step size = 20, gamma = 0.1)
#
# ## Required Libraries
#
# * numpy
# * pandas
# * torch
# * torchvision
# * torchsummary
# * matplotlib
# * scikit-learn
# * seaborn
# * tqdm
# * PIL
#
# ## Dataset
#
# The CIFAR-10 dataset was used for all experiments. The dataset contains 60,000 color images of size 32×32 across 10 classes. The standard split consists of 50,000 training images and 10,000 test images.
#
# ## Results (Best Variants)
#
# | Model                       | Test Accuracy |
# | --------------------------- | ------------: |
# | Modified AlexNet            |        57.72% |
# | VGGNet-19 (Dropout p = 0.3) |        86.75% |
# | ResNet-11                   |        89.08% |
# | ResNet-18                   |        91.04% |
#
#
# For detailed analysis and architectural comparisons, see the accompanying report (PDF).
